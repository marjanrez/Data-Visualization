# %%
import pandas as pd

# %%
df = pd.read_csv('../Data/dfirst100.csv')

# %%
df.tail(5)
# Out:
#          Unnamed: 0 agency_cd   site_no        Date  X_00060_00003  \
# 1601434     1601435      USGS  11015000  2019-10-10            0.0
# 1601435     1601436      USGS  11015000  2019-10-11            0.0
# 1601436     1601437      USGS  11015000  2019-10-12            0.0
# 1601437     1601438      USGS  11015000  2019-10-13            0.0
# 1601438     1601439      USGS  11015000  2019-10-14            0.0
#
#         X_00060_00003_cd
# 1601434                P
# 1601435                P
# 1601436                P
# 1601437                P
# 1601438                P

# %%
df[df.Date=='1962-10-01'].head(10)
# Out:
#         Unnamed: 0 agency_cd   site_no        Date  X_00060_00003  \
# 0                1      USGS  10250800  1962-10-01            0.3
# 10227        10228      USGS  10251300  1962-10-01            0.3
# 28081        28082      USGS  10255700  1962-10-01            0.0
# 40133        40134      USGS  10255800  1962-10-01            1.2
# 52185        52186      USGS  10255810  1962-10-01            0.0
# 81293        81294      USGS  10256000  1962-10-01            9.2
# 91439        91440      USGS  10256500  1962-10-01            2.8
# 180286      180287      USGS  10258000  1962-10-01            0.0
# 210584      210585      USGS  10258500  1962-10-01            0.0
# 236530      236531      USGS  10259000  1962-10-01            0.3
#
#        X_00060_00003_cd
# 0                     A
# 10227                 A
# 28081                 A
# 40133                 A
# 52185                 A
# 81293                 A
# 91439                 A
# 180286                A
# ...

# %%
df['site_no'].nunique()
# Out:
# 98

# %%
df.count()
# Out:
# Unnamed: 0          1601439
# agency_cd           1601439
# site_no             1601439
# Date                1601439
# X_00060_00003       1601065
# X_00060_00003_cd    1601439
# dtype: int64

# %%
df.head(15)
# Out:
#     Unnamed: 0 agency_cd   site_no        Date  X_00060_00003 X_00060_00003_cd
# 0            1      USGS  10250800  1962-10-01            0.3                A
# 1            2      USGS  10250800  1962-10-02            0.3                A
# 2            3      USGS  10250800  1962-10-03            0.3                A
# 3            4      USGS  10250800  1962-10-04            0.3                A
# 4            5      USGS  10250800  1962-10-05            0.3                A
# 5            6      USGS  10250800  1962-10-06            0.4                A
# 6            7      USGS  10250800  1962-10-07            0.4                A
# 7            8      USGS  10250800  1962-10-08            0.4                A
# 8            9      USGS  10250800  1962-10-09            0.4                A
# 9           10      USGS  10250800  1962-10-10            0.4                A
# 10          11      USGS  10250800  1962-10-11            0.4                A
# ...

# %%
df[df.site_no==10250800].count()
# Out:
# Unnamed: 0          9862
# agency_cd           9862
# site_no             9862
# Date                9862
# X_00060_00003       9862
# X_00060_00003_cd    9862
# dtype: int64

# %%
df_sub = df[df.site_no==10250800]

# %%
df_sub.head(5)
# Out:
#    Unnamed: 0 agency_cd   site_no        Date  X_00060_00003 X_00060_00003_cd
# 0           1      USGS  10250800  1962-10-01            0.3                A
# 1           2      USGS  10250800  1962-10-02            0.3                A
# 2           3      USGS  10250800  1962-10-03            0.3                A
# 3           4      USGS  10250800  1962-10-04            0.3                A
# 4           5      USGS  10250800  1962-10-05            0.3                A

# %%
df_sub.tail(5)
# Out:
#       Unnamed: 0 agency_cd   site_no        Date  X_00060_00003  \
# 9857        9858      USGS  10250800  1989-09-26           0.25
# 9858        9859      USGS  10250800  1989-09-27           0.25
# 9859        9860      USGS  10250800  1989-09-28           0.25
# 9860        9861      USGS  10250800  1989-09-29           0.25
# 9861        9862      USGS  10250800  1989-09-30           0.25
#
#      X_00060_00003_cd
# 9857              A e
# 9858              A e
# 9859              A e
# 9860              A e
# 9861              A e

# %%
df_sub['Date'] = pd.to_datetime(df_sub['Date'])
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df_sub.dtypes
# Out:
# Unnamed: 0                   int64
# agency_cd                   object
# site_no                      int64
# Date                datetime64[ns]
# X_00060_00003              float64
# X_00060_00003_cd            object
# dtype: object

# %%
df_sub.groupby(df_sub['Date'].dt.year)['X_00060_00003'].agg(['sum', 'mean', 'max','min'])
# Out:
#          sum      mean     max   min
# Date
# 1962   30.80  0.334783    0.40  0.30
# 1963  106.60  0.292055    0.50  0.20
# 1964  118.50  0.323770    4.10  0.20
# 1965  149.80  0.410411   16.00  0.20
# 1966  179.20  0.490959   31.00  0.20
# 1967  275.50  0.754795  153.00  0.20
# 1968  159.90  0.436885   46.00  0.10
# 1969  716.94  1.964219  432.00  0.17
# 1970   70.24  0.192438    0.51  0.05
# 1971   53.27  0.145945    0.41  0.05
# 1972   73.99  0.202158    9.60  0.10
# 1973   74.06  0.202904    2.20  0.06
# 1974   81.81  0.224137    0.49  0.10
# 1975   88.44  0.242301    0.37  0.13
# 1976  107.30  0.293169    5.90  0.18
# 1977   97.75  0.267808    0.52  0.08
# 1978  171.28  0.469260   34.00  0.08
# 1979   65.09  0.178329    0.91  0.01
# 1980   61.97  0.169317    0.36  0.05
# 1981  105.64  0.289425    9.20  0.10
# 1982   92.09  0.252301    0.50  0.11
# 1983  296.18  0.811452  160.00  0.09
# 1984  146.70  0.400820   21.00  0.06
# 1985  110.05  0.301507    0.66  0.10
# ...

# %%
df_sub_summary = df_sub.groupby(df_sub['Date'].dt.year)['X_00060_00003'].agg(['sum', 'mean', 'max','min'])

# %%
df_sub_summary.columns
# Out:
# Index(['sum', 'mean', 'max', 'min'], dtype='object')

# %%
import matplotlib.pyplot as plt
# %matplotlib inline 
#plt.figure(figsize=(12,6))
df_sub_summary.plot(kind='bar',y='sum')
#plt.bar(height=df_sub_summary['sum'])
plt.title('sum of flow (yearly) in station {}'.format(str(10250800)))
plt.savefig('firstplot.png')
plt.show()

# %%
df_sub_summary.plot(kind='bar',y='mean')
#plt.bar(height=df_sub_summary['sum'])
plt.title('average of flow (yearly) in station {}'.format(str(10250800)))
plt.show()

# %%
df_sub_summary.plot(kind='bar',y='mean')
#plt.bar(height=df_sub_summary['sum'])
plt.title('average of flow (yearly) in station {}'.format(str(10250800)))
plt.show()

# %%
df.tail(5)
# Out:
#          Unnamed: 0 agency_cd   site_no        Date  X_00060_00003  \
# 1601434     1601435      USGS  11015000  2019-10-10            0.0
# 1601435     1601436      USGS  11015000  2019-10-11            0.0
# 1601436     1601437      USGS  11015000  2019-10-12            0.0
# 1601437     1601438      USGS  11015000  2019-10-13            0.0
# 1601438     1601439      USGS  11015000  2019-10-14            0.0
#
#         X_00060_00003_cd
# 1601434                P
# 1601435                P
# 1601436                P
# 1601437                P
# 1601438                P

# %%
df2 = pd.read_csv('../Data/dsecond100.csv')

# %%
df2.head()
# Out:
#    Unnamed: 0 agency_cd   site_no        Date  X_00060_00003 X_00060_00003_cd
# 0           1      USGS  11016200  2005-10-01            0.0              A e
# 1           2      USGS  11016200  2005-10-02            0.0              A e
# 2           3      USGS  11016200  2005-10-03            0.0              A e
# 3           4      USGS  11016200  2005-10-04            0.0              A e
# 4           5      USGS  11016200  2005-10-05            0.0              A e

# %%
df2[df2.site_no==11016200].head(10)
# Out:
#    Unnamed: 0 agency_cd   site_no        Date  X_00060_00003 X_00060_00003_cd
# 0           1      USGS  11016200  2005-10-01            0.0              A e
# 1           2      USGS  11016200  2005-10-02            0.0              A e
# 2           3      USGS  11016200  2005-10-03            0.0              A e
# 3           4      USGS  11016200  2005-10-04            0.0              A e
# 4           5      USGS  11016200  2005-10-05            0.0              A e
# 5           6      USGS  11016200  2005-10-06            0.0              A e
# 6           7      USGS  11016200  2005-10-07            0.0              A e
# 7           8      USGS  11016200  2005-10-08            0.0              A e
# 8           9      USGS  11016200  2005-10-09            0.0              A e
# 9          10      USGS  11016200  2005-10-10            0.0              A e

# %%
df2.dtypes
# Out:
# Unnamed: 0            int64
# agency_cd            object
# site_no               int64
# Date                 object
# X_00060_00003       float64
# X_00060_00003_cd     object
# dtype: object

# %%
df2[df2.site_no==11092450].head(10)
# Out:
#          Unnamed: 0 agency_cd   site_no        Date  X_00060_00003  \
# 1890273     1890274      USGS  11092450  1931-10-01           0.13
# 1890274     1890275      USGS  11092450  1931-10-02           0.10
# 1890275     1890276      USGS  11092450  1931-10-03           0.10
# 1890276     1890277      USGS  11092450  1931-10-04           0.10
# 1890277     1890278      USGS  11092450  1931-10-05           0.10
# 1890278     1890279      USGS  11092450  1931-10-06           0.08
# 1890279     1890280      USGS  11092450  1931-10-07           0.08
# 1890280     1890281      USGS  11092450  1931-10-08           0.10
# 1890281     1890282      USGS  11092450  1931-10-09           0.10
# 1890282     1890283      USGS  11092450  1931-10-10           0.10
#
#         X_00060_00003_cd
# 1890273                A
# 1890274                A
# 1890275                A
# 1890276                A
# 1890277                A
# 1890278                A
# 1890279                A
# ...

# %%
df2_sub = df2[df2.site_no==11092450]

# %%
df2_sub['Date'] = pd.to_datetime(df2_sub['Date'])
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df2_sub_summary=df2_sub.groupby(df2_sub['Date'].dt.year)['X_00060_00003'].agg(['sum', 'mean', 'max','min'])
# Out:
#            sum        mean     max    min
# Date
# 1931    713.10    7.751087   339.0   0.08
# 1932   2510.58    6.859508   826.0   0.05
# 1933   2851.24    7.811616  1010.0   0.10
# 1934   2460.89    6.932085  1910.0   0.03
# 1935   1334.60    3.656438   203.0   0.20
# 1936   1362.80    3.723497   200.0   0.20
# 1937   4977.80   13.637808  1200.0   0.70
# 1938  13238.40   42.981818  5870.0   1.00
# 1939   2635.20    7.219726   460.0   1.80
# 1940   5840.20   15.956831   701.0   1.10
# 1941  26397.50   72.321918  3540.0   5.00
# 1942   3560.00    9.753425    46.0   5.00
# 1943  17207.50   47.143836  2370.0   5.00
# 1944  17596.50   48.077869  4100.0   7.50
# 1945   6554.90   17.958630   452.0   6.50
# 1946   7272.00   19.923288   267.0   5.90
# 1947   5919.60   16.218082   103.0   5.50
# 1948   4371.00   11.942623    73.0   3.30
# 1949   2608.50    7.146575    92.0   3.00
# 1950   2897.30    7.937808   125.0   1.40
# 1951   3319.70    9.095068   343.0   1.30
# ...

# %%
df_sub_summary.plot(kind='bar',y='mean')
#plt.bar(height=df_sub_summary['sum'])
plt.title('average of flow (yearly) in station {}'.format(str(10250800)))
plt.show()
